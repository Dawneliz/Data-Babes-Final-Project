# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
# %matplotlib inline
import statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox

# %%
from pandas import Series, DataFrame

# %%
# Loading Dataset for Per Price Per Barrel

# %%
PriceBarrels = pd.read_excel("C:/Users/dawne/OneDrive/Documents/Gasoline all types in us city urban .xlsx")

# %%
# Take a peek at the data

# %%
PriceBarrels.head()
# Out:
#    Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0  2012  290.762  305.076  329.780  335.742  323.604  303.747  295.498
# 1  2013  286.417  315.243  319.523  307.814  310.352  312.212  310.886
# 2  2014  286.607  289.814  304.464  315.335  317.434  318.334  313.514
# 3  2015  185.142  194.883  215.442  215.461  238.170  244.226  243.736
# 4  2016  171.574  154.564  170.356  185.808  198.011  206.681  195.243
#
#        Aug      Sep      Oct      Nov      Dec    HALF1    HALF2  Unnamed: 15  \
# 0  316.859  329.898  322.934  298.131  285.606  314.785  308.154          NaN
# 1  309.355  305.299  290.306  280.742  282.773  308.594  296.560          NaN
# 2  300.640  294.222  275.729  251.172  223.404  305.331  276.447          NaN
# 3  230.513  207.239  199.077  190.701  179.496  215.554  208.460          NaN
# 4  189.375  193.817  197.357  192.522  195.915  181.166  194.038          NaN
#
#        Annual Unnamed: 17
# 0  311.469750         NaN
# ...

# %%
PriceBarrels.columns
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'HALF1', 'HALF2', 'Unnamed: 15', 'Annual',
#        'Unnamed: 17'],
#       dtype='object')

# %% [markdown]
# # Keep only year and annual

# %%
PriceBarrels1 = PriceBarrels[['Year', 'Annual']]

# %%
PriceBarrels2 = PriceBarrels1.rename(columns={'Year': 'Date'})

# %% [markdown]
# # New Dataset with just the columns we need to do our analysis

# %%
PriceBarrels2.head()
# Out:
#    Date      Annual
# 0  2012  311.469750
# 1  2013  302.576833
# 2  2014  290.889083
# 3  2015  212.007167
# 4  2016  187.601917

# %% [markdown]
# # Load in Gasoline per gallon prices

# %%
PriceGallons = pd.read_excel(r"C:\Users\dawne\OneDrive\Documents\Final Project\GasGallon2002toPresent.xlsx")

# %%
PriceGallons.head()
# Out:
#         Date  USAllAll  EastCoastAllAll  NewEnglandAllAll  \
# 0 1993-04-05     1.068            1.040             1.068
# 1 1993-04-12     1.079            1.047             1.073
# 2 1993-04-19     1.079            1.054             1.074
# 3 1993-04-26     1.086            1.059             1.076
# 4 1993-05-03     1.086            1.062             1.080
#
#    CentralAtlanticAllAll  LowerAtlanticAllAll  MidwestAllAll  GulfCoastAllAll  \
# 0                  1.068                1.023          1.061            1.064
# 1                  1.072                1.032          1.077            1.071
# 2                  1.077                1.040          1.067            1.081
# 3                  1.080                1.046          1.078            1.081
# 4                  1.084                1.050          1.073            1.084
#
#    RockyMountainAllAll  WestCoastAllAll  ...  them  Easy  Names  to  Delete  \
# ...

# %% [markdown]
# # Remove extra dates

# %%
PriceGallons1 = PriceGallons[460:]

# %%
PriceGallons1.head()
# Out:
#           Date  USAllAll  EastCoastAllAll  NewEnglandAllAll  \
# 460 2002-01-28     1.142            1.140             1.196
# 461 2002-02-04     1.157            1.139             1.193
# 462 2002-02-11     1.148            1.143             1.192
# 463 2002-02-18     1.157            1.144             1.197
# 464 2002-02-25     1.157            1.145             1.199
#
#      CentralAtlanticAllAll  LowerAtlanticAllAll  MidwestAllAll  \
# 460                  1.177                1.097          1.104
# 461                  1.173                1.100          1.147
# 462                  1.178                1.103          1.113
# 463                  1.178                1.104          1.125
# 464                  1.183                1.102          1.117
#
#      GulfCoastAllAll  RockyMountainAllAll  WestCoastAllAll  ...  them   Easy  \
# 460            1.088                1.159            1.255  ...   NaN  1.128
# ...

# %%
PriceGallons2 = PriceGallons1[['Date', 'EastCoastAllAll', 'NewEnglandAllAll', 'CentralAtlanticAllAll', 'LowerAtlanticAllAll', 'MidwestAllAll', 'GulfCoastAllAll', 'RockyMountainAllAll', 'WestCoastAllAll', 'USAllAll']]

# %%
PriceGallons2.head()
# Out:
#           Date  EastCoastAllAll  NewEnglandAllAll  CentralAtlanticAllAll  \
# 460 2002-01-28            1.140             1.196                  1.177
# 461 2002-02-04            1.139             1.193                  1.173
# 462 2002-02-11            1.143             1.192                  1.178
# 463 2002-02-18            1.144             1.197                  1.178
# 464 2002-02-25            1.145             1.199                  1.183
#
#      LowerAtlanticAllAll  MidwestAllAll  GulfCoastAllAll  RockyMountainAllAll  \
# 460                1.097          1.104            1.088                1.159
# 461                1.100          1.147            1.087                1.150
# 462                1.103          1.113            1.088                1.145
# 463                1.104          1.125            1.100                1.142
# 464                1.102          1.117            1.101                1.157
#
#      WestCoastAllAll  USAllAll
# ...

# %% [markdown]
# # Turn new data into url into excel format

# %%
PriceGallons2.to_excel('PriceGallons2.xlsx', index=False)

# %%
PriceBarrels2.to_excel('PriceBarrels2.xlsx', index=False)

# %%
#   # Now this data is ready for Tableau #    #

# %%
###############################################################
